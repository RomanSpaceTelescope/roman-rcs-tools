# %% [markdown]
# ## Organization
#
# - Want to organize all important RCS analysis with important data in a Box folder
# * Tuning
# * RCS Precharge
# * RCS Charge Up
# * Integrator
# * Chromatic stability
# * AFT - trending
# * Personality File manipulation
#
# - Want to show the process of dicing up RCS data / and how its grabbed
# - For every RCS chromatic stability - overplot band 4 time series / show how to do this so that someone else can do this
# - All of SCIPA TVAC data in one file
# - list of all the power points, sRCS electronics staiblity with / without thermal control - what is the associated notebook
# - get together with Ed Claybrooks - and understand how to update the mapping using his STOL script / tool
# -- Ed Claybrooks disapears end of December
# Walk through early december with Maxime. Do a knowledge transfer with the science team
#
# Data
